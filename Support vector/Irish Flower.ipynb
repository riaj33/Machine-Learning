# %%
import pandas as pd
from sklearn.datasets import load_iris
iris= load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
df = pd.DataFrame(iris.data, columns = iris.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df["target"]=iris.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df[df.target == 1].head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target
# 50       1
# 51       1
# 52       1
# 53       1
# 54       1

# %%
df["flowers_name"]= df.target.apply(lambda x: iris.target_names[x])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flowers_name
# 0       0       setosa
# 1       0       setosa
# 2       0       setosa
# 3       0       setosa
# 4       0       setosa

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
df0 = df[df.target == 0]
df1 = df[df.target == 1]
df2 = df[df.target == 2]

# %%
df0.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flowers_name
# 0       0       setosa
# 1       0       setosa
# 2       0       setosa
# 3       0       setosa
# 4       0       setosa

# %%
df1.head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target flowers_name
# 50       1   versicolor
# 51       1   versicolor
# 52       1   versicolor
# 53       1   versicolor
# 54       1   versicolor

# %%
df2.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      target flowers_name
# 100       2    virginica
# 101       2    virginica
# 102       2    virginica
# 103       2    virginica
# 104       2    virginica

# %%
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")

plt.scatter(df0["sepal length (cm)"], df0["sepal width (cm)"],color = "g", marker = "+")
plt.scatter(df1["sepal length (cm)"], df1["sepal width (cm)"],color = "m", marker = ".")

# %%
plt.xlabel("petal length")
plt.ylabel("petal width")

plt.scatter(df0["petal length (cm)"], df0["petal width (cm)"],color = "g", marker = "+")
plt.scatter(df1["petal length (cm)"], df1["petal width (cm)"],color = "m", marker = ".")

# %%
x_train = df.drop(["target", "flowers_name"], axis = 1)
x_train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
y_train = df.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size = 0.2)

# %%
print(len(x_train))
print(len(x_test))
# Out:
# 120
# 30

# %%
from sklearn.svm import SVC
model = SVC(C = 10)

# %%
model.fit(x_train, y_train)
# Out:
# SVC(C=10)

# %%
model.score(x_test, y_test)
# Out:
# 0.9666666666666667

# %%
model.predict(x_test)
# Out:
# array([2, 2, 1, 1, 1, 0, 0, 2, 1, 0, 1, 1, 1, 2, 0, 1, 2, 2, 0, 2, 1, 0,
#        0, 2, 0, 2, 2, 1, 2, 1])

# %%
x_test
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 115                6.4               3.2                5.3               2.3
# 138                6.0               3.0                4.8               1.8
# 75                 6.6               3.0                4.4               1.4
# 93                 5.0               2.3                3.3               1.0
# 71                 6.1               2.8                4.0               1.3
# 11                 4.8               3.4                1.6               0.2
# 37                 4.9               3.6                1.4               0.1
# 107                7.3               2.9                6.3               1.8
# 82                 5.8               2.7                3.9               1.2
# 36                 5.5               3.5                1.3               0.2
# 50                 7.0               3.2                4.7               1.4
# ...
